# %%
from IPython.display import display, display_markdown

import pandas as pd
import numpy as np
import subprocess as sp
from filter_cooccurrences import get_terms
from subs2vec.vecs import Vectors
from subs2vec.neighbors import compute_nn

def display_md(md, **kwargs):
    return display_markdown(md, raw=True, **kwargs)

def convert_notebook(title, output='html'):
    convert = sp.run(f'jupyter nbconvert {title}.ipynb --to {output} --output {title}.{output}'.split(' '))
    if convert.returncode == 0:
        display_md(f'Jupyter notebook `{title}` converted successfully.')
    else:
        display_md(f'Error: encountered problem converting Jupyter notebook `{title}`')

# %% [markdown]
# ## Compute and store semantic nearest neighbors for colors and adjectives
# We'll compute the 25 nearest neighbors in the fiction embeddings for each color and adjective in our stimuli. Some neighbors of colors and adjectives will be _other colors and adjectives_, so we'll need to resample/replace those to prevent e.g. removing a color from our corpus entirely and then no longer being able to learn an embedding for that color.

# %%
vecs = Vectors('../embeddings/fic.en.vec', n=1e5, normalize=True)
# Out:
# [INFO] loading vectors ../embeddings/fic.en.vec
# [INFO] <function Vectors.__init__ at 0x1248e0d30> ran in 2.886 seconds

# %%
colors, dimensions = get_terms()
labels = colors + dimensions

# %%
df = compute_nn(vecs, target_vecs=None, target_labels=np.array(labels),
                num_neighbors=1000, whole_matrix=True)
# Out:
# [INFO] <function Vectors.as_dict at 0x1248e0f70> ran in 0.044 seconds
# [INFO] computing analogies using whole matrix additive method
# [INFO] <function compute_nn at 0x1248e0af0> ran in 0.687 seconds

# %%
neighbors = df.values.tolist()
neighbors = [[word for word in words if (('_' not in word) and (word not in labels))] for words in neighbors]
neighbors = [words[:100] for words in neighbors]

# %%
df = pd.DataFrame(neighbors)
df['labels'] = labels
df = df.set_index('labels')
df.to_csv('data/neighbors_coca_fic.tsv', sep='\t', index=False)
display(df)
# Out:
#                       0               1             2           3   \
# labels
# brown           brownish            gray       browned      browns
# blue                gray       bluegreen          pink      violet
# purple           purples         purpled          pink    purplish
# white             whited         whitely        whiten        pink
# green          bluegreen        greenish        greeny        gray
# yellow           yellows       yellowing       yellowy   yellowish
# red              crimson            pink       scarlet    bloodred
# black               gray            dark       blacked    blackish
# orange           oranges            pink       crimson     purples
# happy            unhappy         happier          glad     pleased
# unripe          overripe        ripening       ripened       guava
# hard              harder            Hard     difficult     hardest
# angry            furious           Angry    frustrated       upset
# sad               sadder         unhappy       saddens      lonely
# liked              loved           hated     preferred       likes
# ripe               ripen        ripening       ripened    ripeness
# slow             slowing          slowed          Slow      slower
# dead               dying            Dead      deceased        died
# clean            cleaned          cleans         Clean    cleaning
# exciting      unexciting        Exciting   interesting   thrilling
# calm               calms          calmed         quiet     calming
# alive              Alive           awake         still       dying
# jealous        jealously         Jealous      jealousy  jealousies
# tense             tenses          tensed       tension   tenseness
# heavy              thick           Heavy       heavier     heavies
# new                  New          newest     different       newly
# light           sunlight          lights  illumination        glow
# fast              faster         quickly       rapidly        Fast
# hot               heated            heat        hotter        warm
# selfless    selflessness        devotion     unselfish  courageous
# dirty             filthy        dirtying       dirtied       Dirty
# submissive  submissively      submission   submissions     submits
# active          reactive        actively      inactive   proactive
# dull               dulls          duller        dulled     dulling
# disliked        dislikes         dislike     disliking       hated
# relaxed          Relaxed           relax       relaxes    relaxing
# soft            softness          gentle       softest      softer
# aggressive  aggressively  aggressiveness    aggression  aggressors
# old              ancient           older           Old        aged
# passive        passively       impassive     passivity     Passive
# cold               chill          chilly       chilled      colder
# stale              Stale           musty          odor       stank
# fresh            freshly         fresher         Fresh    freshest
#
#                       4              5            6            7   \
# labels
# brown           browning        browner     blackish          tan
# blue               blued        crimson       maroon    turquoise
# purple            violet       purpling     lavender      scarlet
# white          whitening           gray      whitest     whitened
# green             greens        purples     greening      yellows
# yellow          yellowed           pink      crimson     greenish
# red              reddish      vermilion      pinking       redder
# black              Black     collarless      colored      blacker
# orange         tangerine        yellows   chartreuse       violet
# happy           happiest      delighted        Happy     grateful
# unripe          honeydew          fruit       apples     apricots
# hard               tough         harden    Difficult         easy
# angry           confused        angrier      annoyed   frightened
# sad         disappointed      sorrowful     saddened      saddest
# liked             wanted          Liked      enjoyed         knew
# ripe            overripe          fruit      peaches       apples
# slow             slowest         steady       uptake      Slowing
# dead             corpses         corpse       killed     unburied
# clean           spotless       cleanser     scrubbed         wash
# exciting         excited   exhilarating  adventurous  fascinating
# calm            calmness         serene       calmer         Calm
# alive               here         intact         safe      healthy
# jealous          zealous          upset          mad     Jealousy
# tense            tensely        anxious      nervous      tensing
# heavy            weighty          dense     weighted       weight
# new               latest          newer      replace      changer
# light         floodlight    illuminated   streetlamp  streetlight
# fast               speed           soon       Faster        quick
# hot            scorching            Hot       steamy        humid
# selfless    praiseworthy  compassionate  egotistical  commendable
# dirty              grimy        stained        filth       soiled
# submissive        submit     permissive   dismissive      missive
# active            Active       activity     activism  interactive
# dull               dully        dullest     dullness        muted
# disliked         loathed          loved     despised     resented
# relaxed       relaxation    comfortable    lightened    tightened
# soft               silky           Soft         warm       smooth
# aggressive     aggressor     repressive  progressive         sive
# old                oldie           ugly     decrepit        aging
# passive      passionless    emotionless  impassively      Massive
# cold              frigid            icy     freezing         warm
# stale             reeked          odour      smelled       mildew
# fresh            freshen         afresh      Freshly   freshening
#
#                        8             9   ...             90             91  \
# labels                                   ...
# brown             colored          grey  ...           rust          amber
# blue               cobalt       purples  ...     coloration       ribboned
# purple            crimson        Purple  ...          puffy           puce
# white              whiter       colored  ...     iridescent          voile
# green             greened          teal  ...         sienna          beige
# yellow            purples        Yellow  ...        Reddish       burgundy
# red             splotched        violet  ...         golden         tinted
# black           sharkskin   formfitting  ...      leathered         finned
# orange            magenta        Orange  ...        paisley     discolored
# happy           contented       content  ...            hap      energetic
# unripe            peaches         tripe  ...          chard      goldenrod
# hard              hardens       toughen  ...         smooth          right
# angry           irritated           mad  ...        Enraged        nervous
# sad               sadness    melancholy  ...          silly    reproachful
# liked             admired         cared  ...         minded          Hated
# ripe          watermelons        grapes  ...     Watermelon          chewy
# slow               slowly      slowdown  ...          crawl       measured
# dead             murdered      lifeless  ...       headless    decomposing
# clean           cleansers      cleanest  ...      dishcloth         linens
# exciting           excite       excites  ...      embarking    unglamorous
# calm                 cool      becalmed  ...          lulls          civil
# alive              killed        harmed  ...           stUl       outlived
# jealous           envious         bossy  ...       bitching      flattered
# tense             worried         Tense  ...        annoyed       hesitant
# heavy            heaviest       heavily  ...       brocaded        quilted
# new              brandnew   replacement  ...  incorporation          fusty
# light          brightness  illuminating  ...       penlight   searchlights
# fast              swiftly         rapid  ...    fishtailing       airspeed
# hot                  cool         muggy  ...           hoth        sweated
# selfless       devotional    compassion  ...      adoration    disciplined
# dirty              grubby         dingy  ...         Greasy      yellowish
# submissive     submitting          meek  ...  condescension      prayerful
# active         responsive      activist  ...     proficient     inactivity
# dull               boring      listless  ...         drudge     transmuted
# disliked         detested     preferred  ...         liking       distrust
# relaxed             eased     contented  ...    unclenching    reholstered
# soft             whispery  comfortingly  ...        squishy          rough
# aggressive     expressive  intimidating  ...        unmanly  overconfident
# old               elderly       younger  ...         tatted      crumbling
# passive     unthreatening    responsive  ...         silent      undefined
# cold                 Cold       coldest  ...           snow         thawed
# stale               smell          sour  ...         fruity     stagnation
# fresh             refresh     freshness  ...     springtime         spritz
#
#                          92               93             94             95  \
# labels
# brown                  lank            tawny        grained         violet
# blue              splotches          fringed        grayish       pinafore
# purple           tourmaline       discolored          bluer      flowering
# white               purples         ribboned     unwrinkled      gabardine
# green            loopleaves    monochromatic        fuchsia      hyacinths
# yellow             staining           leaved       squiggly    cornflowers
# red                staining         blinking        browned    heartshaped
# black               worsted      barechested   multicolored        speckle
# orange               bright      buttercream          ovoid    pomegranate
# happy             beautiful         mirthful     interested      expectant
# unripe             ocotillo            phlox     sweetmeats      garnished
# hard                 unable      backpedaled      ingrained          lever
# angry               puzzled      disappoints         sullen    overexcited
# sad              heartbreak          despair          proud          bleak
# liked               fancied         appealed        assumed          about
# ripe               mycowood      blueberries        honeyed      pubescent
# slow        synchronization        glutinous  imperceptibly         motion
# dead              butchered             limp       cadavers         fallen
# clean                 neath      greasepaint         dusted        ammonia
# exciting           scariest       gratifying      appealing      inclusive
# calm                panicky      seriousness     untroubled  authoritative
# alive           reconnected           bested    nourishment     nourishing
# jealous              hungry         outshone      attracted       despises
# tense             irritated      uncertainty          stiff    lightheaded
# heavy                Layers             iron      sheathing   welterweight
# new                  buying         newfound       upgrades      modernize
# light            glimmering        lightness     lightening   semidarkness
# fast            backpedaled        furiously   acceleration       Speeding
# hot                   warms           burner       heatedly           sore
# selfless       faithfulness  competitiveness  individualism       creative
# dirty                   mud         cleanest         washed        dishing
# submissive      superiority     aggressively     gentleness       wrathful
# active           exhaustive        incentive       positive   participants
# dull                 pyrite           torpid       ringless         watery
# disliked           snobbish       criticized        because      ridiculed
# relaxed         nonchalance             taut         tented   comfortingly
# soft              hollowing          quivery          crisp           bare
# aggressive        unusually       motivating     antisocial     inhibiting
# old                bachelor     octogenarian   Barcalounger      towheaded
# passive          compulsive            Stoic       listless  undisciplined
# cold                    raw           misted           dark      blizzards
# stale            putrefying        coriander          minty       aromatic
# fresh              ripening         hardtack    vinaigrette          sours
#
#                         96            97                 98              99
# labels
# brown                plaid        grayed           staining     houndstooth
# blue               roseate     speckling               hues       yellowish
# purple             leotard    monochrome               gold         gaudily
# white              gaudily       striped       immaculately         painted
# green               lucent   iridescence     bioluminescent           ocher
# yellow              pastel       whitely             glowed          lucent
# red                   pale       stripes             colors          dirndl
# black                color     whitening             eyelet            pink
# orange                puce         mauve       fluorescents       turquoise
# happy           satisfying       beaming         loquacious       depressed
# unripe          cornstalks         husks           mulberry        unpeeled
# hard               pounded        soften         hardheaded             wet
# angry           ungrateful       hateful           snappish     Embarrassed
# sad                   glum       bashful           Pathetic      fatherless
# liked             deserved        better            loathes        mothered
# ripe                 seeds         heady           redolent           guava
# slow                 movin  breaststroke               beat        coasting
# dead                 Alive     faithless       assassinated            here
# clean                towel        soaped            dishpan            gunk
# exciting        unoriginal     happening        enthralling   fantastically
# calm           passionless   levelheaded            quieter       steadfast
# alive             infected      credited            Antares     Unconscious
# jealous           obsessed    irrational          irritated       impressed
# tense             spasming      suddenly          irritable       terrified
# heavy               loaded     balaclava           muffling         grained
# new              fantastic   neighboring      bioengineered        freshest
# light            fireflies        shines             aurora        shimmers
# fast                nimble    recklessly               down           steep
# hot           temperatures       kettles        temperature        prickles
# selfless    vindictiveness      quixotic         dedicating         commend
# dirty                   Tz         cheap           streaked          coarse
# submissive     unambiguous    apologetic           response        obdurate
# active           Auxiliary      espoused         organizing       expedient
# dull          monotonously      dreadful              faint          dreary
# disliked         impressed     endearing           insisted   unembarrassed
# relaxed          squinched  businesslike    unselfconscious      liveliness
# soft              gentlest      feathery              duvet           linty
# aggressive   progressively  ingratiating     disciplinarian    closemouthed
# old              doddering           who           icehouse       mothballs
# passive       indifference          sive  misinterpretation  pathologically
# cold                gritty        stings              moist           humid
# stale            stalemate       pungent              gummy          rotten
# fresh           seasonings      packaged          basketful       delicious
#
# [43 rows x 100 columns]

# %%
convert_notebook('get_nearest_neighbors')
# Out:
# [NbConvertApp] Converting notebook get_nearest_neighbors.ipynb to html
# [NbConvertApp] Writing 615898 bytes to get_nearest_neighbors.html
# Jupyter notebook `get_nearest_neighbors` converted successfully.
